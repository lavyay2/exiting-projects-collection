# %% [markdown]
# <a href="https://colab.research.google.com/github/lavyay2/exiting-projects-collection/blob/main/Copy_of_Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Project Name**    -**UBER SUPPLY DEMAND GAP**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
#
# This project analyzes the supply and demand gap of Uber rides to and from the airport. The dataset contains information about Uber requests, including pickup and drop-off points, timestamps, and request status (completed, cancelled, or no cars available).
#
# The analysis focuses on identifying patterns in demand and supply across different times of the day and pickup locations. Key findings include:
#
# Peak Hours: The highest demand for Uber rides is observed during specific time slots, particularly during morning and evening rush hours.
# Location-Based Discrepancies: There are significant differences in the supply-demand gap between airport and city locations.
# Cancellation and No Availability: A considerable number of requests are either cancelled or have no cars available, highlighting the supply challenges.
# The project delves into the characteristics of completed, cancelled, and no-car-available trips to understand the factors contributing to unfulfilled requests. This includes analyzing trip durations, driver activity, and the distribution of requests across different time slots and days of the week.
#
# Visualizations such as bar charts, line plots, and heatmaps are used to illustrate these findings and provide insights into the underlying patterns. The analysis aims to provide actionable recommendations to bridge the supply-demand gap and improve the efficiency of Uber's operations, particularly for airport transportation.
#
# Further analysis could involve exploring external factors such as flight schedules, traffic conditions, and special events that might influence demand and supply. Additionally, predictive modeling techniques could be employed to forecast demand and optimize driver allocation.
#
# Overall, this project provides a comprehensive analysis of the Uber supply-demand gap, offering valuable insights for improving service quality and operational efficiency.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
# The primary business objective is to reduce the supply-demand gap in Uber rides, specifically for airport transportation.
#
# This aims to improve operational efficiency, increase the number of completed trips, and enhance customer satisfaction by minimizing unfulfilled requests and optimizing driver availability at peak times and locations.
#
# The primary problem is the significant supply-demand gap in Uber rides, focusing on airport transportation. This leads to many unfulfilled requests (Cancelled or No Cars Available).
#
# The project aims to:
#
# 1 dentify the extent and nature of this gap.
#
# 2 Determine key contributing factors.
#
# 3 Pinpoint critical times and locations of imbalance.
#
# 4 Provide data-driven insights to bridge the gap and improve operational efficiency and customer satisfaction.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer   The primary business objective is to reduce the supply-demand gap in Uber rides, specifically for airport transportation.
#
# This aims to improve operational efficiency, increase the number of completed trips, and enhance customer satisfaction by minimizing unfulfilled requests and optimizing driver availability at peak times and locations.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
pd.read_csv('/content/Uber Request Data.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df = pd.read_csv('/content/Uber Request Data.csv')
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer  The dataset contains 6745 rows and 6 columns.
# The columns are: 'Request id', 'Pickup point', 'Driver id', 'Status', 'Request timestamp', and 'Drop timestamp'.
# There are no duplicate rows in the dataset.
# The 'Driver id' and 'Drop timestamp' columns have missing values. Specifically, 'Driver id' has 2650 missing values and 'Drop timestamp' has 3914 missing values.
# The data types of the columns are: 'Request id' (int64), 'Pickup point' (object), 'Driver id' (float64), 'Status' (object), 'Request timestamp' (object), and 'Drop timestamp' (object).
# The 'Request timestamp' and 'Drop timestamp' columns are currently stored as objects and will need to be converted to datetime objects for time-based analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here is a description of the variables in the dataset:
#
# Request id: Unique identifier for each Uber request (integer).
#
# Pickup point: The location where the Uber ride was requested from (categorical - object).
#
# Driver id: Unique identifier for the driver who accepted the request (float64). This column has missing values, indicating requests that were not accepted by a driver.
#
# Status: The current status of the request (categorical - object). This can be 'Trip Completed', 'Cancelled', or 'No Cars Available'.
#
# Request timestamp: The timestamp when the request was made (object). This will need to be converted to a datetime object for analysis.
#
# Drop timestamp: The timestamp when the trip was completed (object). This column has missing values for requests that were cancelled or had no cars available. This will also need to be converted to a datetime object for analysis.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Convert timestamp columns to datetime objects
df['Request timestamp'] = pd.to_datetime(df['Request timestamp'], errors='coerce')
df['Drop timestamp'] = pd.to_datetime(df['Drop timestamp'], errors='coerce')

# Extract time-based features
df['Request hour'] = df['Request timestamp'].dt.hour
df['Request Day of Week'] = df['Request timestamp'].dt.day_name()
df['Request Month'] = df['Request timestamp'].dt.month
df['Request Year'] = df['Request timestamp'].dt.year

# Calculate trip duration for completed trips
df['Trip Duration'] = (df['Drop timestamp'] - df['Request timestamp']).dt.total_seconds() / 60

# Display the first few rows with new columns
display(df.head())

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer    I converted the timestamp columns to datetime objects and extracted time features like hour, day of the week, month, and year. I also calculated the trip duration for completed rides.
# These steps allow us to analyze:
#
# **When people** request Ubers (peak hours, days, etc.).
#
# **How long** completed trips take.
#
# This information is key to understanding the supply and demand patterns.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
status_counts = df['Status'].value_counts()

plt.figure(figsize=(8, 6))
sns.barplot(x=status_counts.index, y=status_counts.values, palette='viridis')
plt.title('Distribution of Uber Request Status')
plt.xlabel('Status')
plt.ylabel('Number of Requests')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
# I chose a bar chart to visualize the distribution of Uber request statuses because it's an effective way to compare the counts of different categorical variables (Trip Completed, Cancelled, No Cars Available). Bar charts make it easy to see which status has the highest or lowest frequency.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer  I need to see the output of the chart first to tell you the exact insights. However, generally, this chart will show the number of requests for each status (Completed, Cancelled, No Cars Available). We'll be able to see which status is most frequent and understand the overall proportion of successful trips versus unfulfilled requests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer  Yes, the insights from the request status distribution chart can definitely help create a positive business impact.
#
# By understanding the proportion of cancelled requests and requests with no cars available, Uber can identify the severity of the supply-demand gap. This knowledge can inform strategies to:
#
# **Increase driver availability:**
#  If "No Cars Available" is high, Uber can focus on recruiting more drivers, especially during peak hours or in specific locations where this is a major issue.
#
# **Reduce cancellations:**
#  If cancellations are high, Uber can investigate the reasons behind them (e.g., long waiting times, driver behavior, pricing) and implement solutions to reduce them.
#
# **Optimize resource allocation:**
#  By knowing when and where requests are unfulfilled, Uber can better allocate drivers to meet the demand.
#
#  Identifying and addressing the reasons for unfulfilled requests directly contributes to improving customer satisfaction, increasing completed trips, and ultimately driving positive business growth.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
status_by_pickup = df.groupby('Pickup point')['Status'].value_counts().unstack()

status_by_pickup.plot(kind='bar', figsize=(10, 6))
plt.title('Uber Request Status Distribution by Pickup Point')
plt.xlabel('Pickup Point')
plt.ylabel('Number of Requests')
plt.xticks(rotation=0)
plt.legend(title='Status')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Answer** I chose a grouped bar chart to visualize the Uber request status distribution by pickup point because it allows for a direct comparison of the 'Status' categories ('Trip Completed', 'Cancelled', 'No Cars Available') within each 'Pickup point' ('Airport' and 'City'). This makes it easy to see if the proportion of each status differs depending on where the ride was requested.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer  I chose a grouped bar chart to visualize the Uber request status distribution by pickup point because it allows for a direct comparison of the 'Status' categories ('Trip Completed', 'Cancelled', 'No Cars Available') within each 'Pickup point' ('Airport' and 'City'). This makes it easy to see if the proportion of each status differs depending on where the ride was requested.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer   Yes, the insights from the grouped bar chart showing request status by pickup point are very valuable for creating a positive business impact.
#
# By understanding where the supply-demand gap is most prominent (Airport or City) and the specific nature of the issues (cancellations or no cars available) in each location, Uber can tailor its strategies effectively. For example:
#
# Targeted Driver Recruitment: If the chart shows a high number of "No Cars Available" requests at the Airport during certain times, Uber can focus on incentivizing drivers to be available at the airport during those periods.
# Location-Specific Promotions: If cancellations are high in the City, Uber might investigate if surge pricing or estimated arrival times are contributing factors and adjust accordingly.
# Improved Resource Allocation: Knowing the demand patterns at each location allows for better distribution of available drivers, reducing wait times and increasing completed trips.
# Identifying areas with a high proportion of unfulfilled requests (cancellations and no cars available) highlights areas of negative growth, as these represent lost revenue opportunities and potentially dissatisfied customers. By addressing these location-specific issues, Uber can improve its service efficiency, increase completed trips, and ultimately drive positive business growth.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
status_by_hour = df.groupby('Request hour')['Status'].value_counts().unstack().fillna(0)

status_by_hour.plot(kind='bar', stacked=True, figsize=(12, 7))
plt.title('Uber Request Status Distribution by Hour of the Day')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Requests')
plt.xticks(rotation=0)
plt.legend(title='Status')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer I chose a stacked bar chart to visualize the Uber request status distribution by hour of the day because it's a great way to see the total number of requests at each hour and, more importantly, how that total is divided among the different statuses ('Trip Completed', 'Cancelled', and 'No Cars Available'). This helps us quickly identify the hours where unfulfilled requests (cancelled or no cars available) are most prevalent and understand their proportion relative to completed trips during those times.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Looking at the chart, here are some key insights:
#
# Peak Demand Hours:    There are clear peak hours for Uber requests. We can observe a significant number of requests during certain times of the day.
#
# Morning Rush (Around 5-9 AM):    During the morning hours, there is a high number of cancelled requests and completed trips. This suggests high demand from the city, but also potential issues with driver availability leading to cancellations.
#
# Evening Rush (Around 5-10 PM):  The evening hours show a substantial number of "No Cars Available" requests, particularly for Airport pickups. This indicates a significant supply shortage during this time, likely due to high demand from the airport to the city.
# Differences in Status Distribution Throughout the Day: The proportion of 'Trip Completed', 'Cancelled', and 'No Cars Available' statuses varies significantly throughout the day, highlighting the dynamic nature of the supply-demand gap.
#
#  The stacked bars clearly show that the "No Cars Available" status forms a large portion of the requests in the evening, indicating a lack of available drivers to meet the demand.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Yes, the insights gained from the chart showing request status distribution by hour are highly valuable for creating a positive business impact.
#
# By identifying the specific hours of the day when cancellations and "No Cars Available" requests are most prevalent, Uber can implement targeted strategies to address these issues during those critical periods. This could include:
#
# Incentivizing drivers: Offering incentives to drivers to be available during peak demand hours, especially in locations with high "No Cars Available" rates.
# Dynamic pricing adjustments: Implementing dynamic pricing strategies during peak hours to balance supply and demand (although this needs careful consideration to avoid excessive cancellations due to high prices).
# Improved demand forecasting: Using the hourly data to refine demand forecasting models and better anticipate the number of drivers needed at different times.
# Targeted communication: Communicating with drivers about the peak demand hours and locations to encourage them to be online during those times.
# The insights that lead to negative growth are the high numbers of "Cancelled" and "No Cars Available" requests during specific hours. These represent lost revenue and potentially dissatisfied customers who might turn to alternative transportation options in the future. By focusing on resolving the issues during these identified peak problem hours, Uber can significantly improve its service reliability, increase completed trips, and ultimately drive positive business growth

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Create time slots
def get_time_slot(hour):
    if 4 <= hour < 10:
        return 'Morning'
    elif 10 <= hour < 16:
        return 'Daytime'
    elif 16 <= hour < 22:
        return 'Evening'
    else:
        return 'Night'

df['Time Slot'] = df['Request hour'].apply(get_time_slot)

# Group by pickup point and time slot, then count status
status_by_pickup_timeslot = df.groupby(['Pickup point', 'Time Slot'])['Status'].value_counts().unstack().fillna(0)

status_by_pickup_timeslot.plot(kind='bar', stacked=True, figsize=(14, 7))
plt.title('Uber Request Status Distribution by Pickup Point and Time Slot')
plt.xlabel('Pickup Point and Time Slot')
plt.ylabel('Number of Requests')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Status')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer  I used a stacked bar chart to show how request statuses are distributed by both pickup point and time of day, making it easy to compare the breakdown across different locations and times.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Looking at the chart showing Uber request status distribution by pickup point and time slot, here are some insights:
#
# Morning Rush (City to Airport): There's a significant number of cancelled requests from the City during the Morning time slot (4 AM to 10 AM).
#
# This suggests that many people requesting rides from the City to the Airport in the morning are unable to get one, likely due to a shortage of drivers in the City willing to go to the Airport during that busy time.
#
# Evening Rush (Airport to City):
# The Evening time slot (4 PM to 10 PM) shows a large number of "No Cars Available" requests from the Airport. This indicates a severe shortage of drivers at the Airport during this period, likely because many drivers are in the City and there's high demand from the Airport to the City.
#
# Daytime and Nighttime: The Daytime and Nighttime slots generally show a higher proportion of "Trip Completed" requests compared to the rush hours, although there are still some unfulfilled requests. The "No Cars Available" issue at the Airport is particularly prominent during the Night time slot as well.
#
# Comparison between City and Airport:
#
# The chart clearly highlights that the nature of the supply-demand gap differs between the City and the Airport and varies throughout the day. The City seems to have more issues with cancellations in the morning, while the Airport has a significant problem with "No Cars Available" in the evening and night.
#
# These insights pinpoint the specific times and locations where the supply-demand imbalance is most critical and the nature of the problem (cancellation or no car availability).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer es, understanding the supply-demand gap by location and time helps Uber target resources effectively (positive impact). High unfulfilled requests in specific time slots and locations show negative growth due to lost business and potential customer dissatisfaction.

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# Chart 5: analyze trip duration distribution
# Subtask:
# Create a histogram or box plot to visualize the distribution of trip durations for completed trips. Answer the standard questions for this chart.
#
# Reasoning: Filter the DataFrame to get completed trips and then create a histogram to visualize the distribution of trip durations.

# %%
# Chart - 5 visualization code

completed_trips_df = df[(df['Status'] == 'Trip Completed') & (df['Trip Duration'].notnull())]

plt.figure(figsize=(10, 6))
sns.histplot(data=completed_trips_df, x='Trip Duration', bins=50, kde=True)
plt.title('Distribution of Trip Durations for Completed Trips')
plt.xlabel('Trip Duration (minutes)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer  I chose a histogram to visualize the distribution of trip durations for completed trips because it effectively shows the frequency of different trip lengths. It helps us understand the typical duration of completed rides and identify if there are any unusually long or short trips. The KDE (Kernel Density Estimate) line is added to show the estimated probability density function, giving a smoothed representation of the distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Looking at the histogram of trip durations for completed trips, here are some insights:
#
# Typical Trip Duration: The majority of completed trips fall within a certain range, likely indicating common travel times for successful Uber rides in this dataset. We can observe a peak in the histogram which represents the most frequent trip duration.
#
# Distribution Shape: The distribution appears to be right-skewed, meaning there are some longer trips that extend the tail of the distribution to the right.
#
# Outliers: There might be some outliers representing unusually long trips, which could be due to various factors like traffic, distance, or other delays.
# Understanding the typical trip duration and the spread of trip lengths can help Uber estimate arrival times more accurately and optimize routing.
#
# Identifying unusually long trips might warrant further investigation into potential issues.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer The insights from the trip duration histogram can definitely help create a positive business impact.
#
# Understanding the typical trip duration allows Uber to:
#
# Improve ETA Accuracy: More accurate estimated arrival times can improve customer satisfaction and reduce cancellations due to long waits.
#
# Optimize Driver Routing and Allocation: By knowing typical trip lengths from different locations, Uber can better estimate driver availability and optimize dispatching to reduce downtime between trips.
#
# Identify Operational Issues: Unusually long trip durations could indicate traffic problems, inefficient routes, or other operational issues that need to be addressed to improve efficiency and driver utilization.
#
# Insights that could indicate negative growth are the presence of a significant number of unusually long trips (outliers).
#
# While some long trips are expected, a high frequency of excessively long trips could point to inefficiencies in the system, potentially leading to lower driver earnings per hour and increased customer dissatisfaction due to extended travel times.
#
# Addressing the root causes of these long trips is crucial for improving service quality and preventing negative growth.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Scatter plot of Request Hour vs. Trip Duration for completed trips
plt.figure(figsize=(10, 6))
sns.scatterplot(data=completed_trips_df, x='Request hour', y='Trip Duration', alpha=0.5)
plt.title('Scatter Plot of Request Hour vs. Trip Duration (Completed Trips)')
plt.xlabel('Request Hour')
plt.ylabel('Trip Duration (minutes)')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#  I chose a scatter plot to visualize the relationship between 'Request hour' and 'Trip Duration' for completed trips because scatter plots are effective in showing the potential correlation or patterns between two numerical variables. By plotting each completed trip as a point with its request hour on the x-axis and its duration on the y-axis, we can observe if there's any trend or clustering of trip durations at different hours of the day. This helps to see if trips are generally longer or shorter during specific times.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Answer Here**
#
# Looking at the scatter plot of 'Request hour' vs. 'Trip Duration' for completed trips, here are some potential insights:
#
# *   **No strong linear correlation:** There doesn't appear to be a clear linear relationship between the hour of the day and the trip duration. The points are quite scattered.
# *   **Variability in trip duration:** For almost every hour of the day, there is a wide range of trip durations, indicating that trip length is not solely determined by the time of the request.
# *   **Potential clusters or patterns:** While there's no strong correlation, there might be some hours where a higher concentration of longer or shorter trips occur. For example, we might observe more longer trips during peak traffic hours, although this isn't immediately obvious from a simple scatter plot without further analysis or aggregation.
#
# Further analysis, perhaps by looking at average trip duration per hour or visualizing density, might reveal more subtle patterns.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer
#
# The insights from the scatter plot of 'Request hour' vs. 'Trip Duration' for completed trips have a moderate potential for positive business impact, primarily by highlighting the variability in trip durations at different hours.
#
# **Positive Business Impact:**
#
# *   **Improved ETA Accuracy:** While there's no strong linear correlation, understanding that trip durations vary significantly within each hour can help Uber refine their estimated arrival time (ETA) calculations. Instead of relying solely on distance and time of day, they might need to incorporate other factors or use more sophisticated models that account for this variability. More accurate ETAs lead to improved customer satisfaction.
# *   **Operational Planning:** Recognizing the range of trip durations at different times can inform operational planning, such as driver scheduling and dispatching. For example, if certain hours consistently show a wider spread of trip durations, it might indicate unpredictable traffic conditions that require more buffer time in scheduling.
#
# **Insights that could lead to negative growth:**
#
# *   **Unpredictability:** The lack of a strong pattern and the high variability in trip durations at any given hour suggest a degree of unpredictability in trip completion times. This unpredictability can lead to:
#     *   **Driver Frustration:** Drivers might find it difficult to estimate their earnings and schedule their work effectively if trip durations are highly variable.
#     *   **Customer Dissatisfaction:** While ETAs can be improved, significant deviations from the estimate due to unpredictable trip durations can still lead to frustrated customers.
#     *   **Inefficient Resource Utilization:** Unpredictable trip durations can make it harder to efficiently allocate drivers, potentially leading to longer wait times for riders or idle time for drivers.
#
# While the scatter plot doesn't show direct negative growth metrics like cancellations, the underlying unpredictability it reveals can indirectly contribute to negative growth by impacting driver and customer experience and operational efficiency. Addressing the factors contributing to this variability (e.g., traffic congestion, inefficient routing) is crucial for mitigating potential negative impacts.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

plt.figure(figsize=(5, 5))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Uber Request Status')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Answer**
# I chose a pie chart to visualize the distribution of Uber request statuses because it is an effective way to show the proportion of each category ('Trip Completed', 'Cancelled', 'No Cars Available') relative to the whole number of requests. It quickly provides a clear visual representation of how the total requests are divided among the different statuses, making it easy to see which status is most frequent and the relative size of the unfulfilled requests.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Answer **
#
# Looking at the pie chart showing the distribution of Uber request statuses, here are the key insights:
#
# *   **Significant number of unfulfilled requests:** The chart clearly shows that a large portion of Uber requests are not completed. Combining the 'Cancelled' and 'No Cars Available' segments reveals the overall percentage of requests that did not result in a completed trip.
# *   **Proportion of each status:** The chart directly provides the percentage of requests for each status: 'Trip Completed', 'Cancelled', and 'No Cars Available'. This allows for a quick comparison of the frequency of each outcome.
# *   **Identification of the biggest issue:** By looking at the largest segments among the unfulfilled requests ('Cancelled' and 'No Cars Available'), we can identify which specific issue (cancellations or lack of cars) contributes more to the supply-demand gap.
#
# These insights provide a high-level overview of the success rate of Uber requests and highlight the magnitude of the problem of unfulfilled rides.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer**
#
# Yes, the insights from the pie chart on Uber request status distribution are crucial for creating a positive business impact.
#
# **Positive Business Impact:**
#
# *   **Quantifying the Problem:** The pie chart clearly quantifies the proportion of unfulfilled requests. This provides a clear understanding of the magnitude of the supply-demand gap, which is the primary business problem. Knowing the percentage of requests that are cancelled or have no cars available allows Uber to set specific, measurable goals for improvement.
# *   **Prioritization of Issues:** By showing the relative size of the 'Cancelled' and 'No Cars Available' segments, the chart helps Uber prioritize which issue to address first. If 'No Cars Available' is a much larger slice, the focus should be on increasing driver supply or optimizing driver allocation. If 'Cancelled' is larger, the focus might shift to understanding and mitigating reasons for cancellations (e.g., long wait times, pricing).
#
# **Insights that could lead to negative growth:**
#
# *   **High proportion of unfulfilled requests:** The significant percentage of requests that are either 'Cancelled' or result in 'No Cars Available' directly represents lost revenue and potential negative growth. Each unfulfilled request is a missed business opportunity.
# *   **Customer Dissatisfaction:** A high rate of unfulfilled requests leads to frustrated customers who may switch to competitor services, resulting in a loss of market share and negative business growth.
# *   **Driver Inefficiency:** If drivers are frequently unable to accept requests due to distance or other factors leading to 'No Cars Available', it can indicate inefficiencies in the dispatching system or a mismatch between driver location and rider demand, impacting driver earnings and potentially leading to driver churn.
#
# Therefore, while the pie chart itself is a high-level summary, the insights it provides about the magnitude and nature of the unfulfilled requests are fundamental to identifying areas of negative growth and formulating strategies for positive business impact.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
status_by_day = df.groupby('Request Day of Week')['Status'].value_counts().unstack().fillna(0)

# Define the order of days of the week for proper plotting
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
status_by_day = status_by_day.reindex(day_order).fillna(0)


status_by_day.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Uber Request Status Distribution by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Requests')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Status')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Answer **
#
# I chose a stacked bar chart to visualize the Uber request status distribution by day of the week because it allows us to see the total number of requests for each day and how those requests are broken down by status ('Trip Completed', 'Cancelled', 'No Cars Available'). This makes it easy to compare the proportion of unfulfilled requests across different days and identify if certain days have a higher rate of cancellations or no cars available.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Answer **
#
# Looking at the stacked bar chart showing Uber request status distribution by day of the week, here are some key insights:
#
# *   **Data Limitation:** The chart primarily shows data for only two days: Monday and Wednesday. There are no requests recorded for Tuesday, Thursday, Friday, Saturday, or Sunday in this dataset. This is a significant limitation in understanding the weekly patterns.
# *   **Comparison between Monday and Wednesday:** Based on the available data for Monday and Wednesday:
#     *   Both days show a substantial number of unfulfilled requests (Cancelled and No Cars Available).
#     *   The total number of requests appears to be slightly higher on Monday than on Wednesday.
#     *   The proportion of 'No Cars Available' requests seems to be higher than 'Cancelled' requests on both days.
# *   **Need for Complete Data:** Due to the missing data for most days of the week, it is not possible to draw comprehensive conclusions about how the supply-demand gap varies throughout the entire week.
#
# The primary insight from this chart is the incompleteness of the data regarding the days of the week, which limits the ability to analyze weekly trends in Uber request statuses.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer **
#
# The insights gained from this chart regarding the distribution of Uber request statuses by day of the week are **limited in their direct business impact** due to the incomplete data (only Monday and Wednesday are represented).
#
# **Limited Positive Business Impact:**
#
# *   Based *only* on the limited data for Monday and Wednesday, one can infer that both days experience a significant number of unfulfilled requests. This reinforces the overall finding about the supply-demand gap, but it doesn't provide enough information to identify specific daily trends or plan strategies for other days of the week.
#
# **Insights that could lead to negative growth:**
#
# *   The presence of unfulfilled requests (Cancelled and No Cars Available) on both Monday and Wednesday, as shown in the chart, represents lost revenue and potential customer dissatisfaction for those specific days. However, without data for the full week, we cannot determine if certain days have significantly worse performance than others.
#
# **Overall:** The primary insight from this chart is the **need for more complete data** to fully understand the weekly patterns of the supply-demand gap and make informed decisions for positive business impact. Analyzing a complete week's data would be crucial to identify specific days with critical imbalances and tailor operational strategies accordingly.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Filter for unfulfilled requests (Cancelled or No Cars Available)
unfulfilled_df = df[df['Status'].isin(['Cancelled', 'No Cars Available'])]

# Group by pickup point and time slot, then count status
unfulfilled_by_pickup_timeslot = unfulfilled_df.groupby(['Pickup point', 'Time Slot'])['Status'].value_counts().unstack().fillna(0)

unfulfilled_by_pickup_timeslot.plot(kind='bar', figsize=(12, 7))
plt.title('Unfulfilled Requests (Cancelled and No Cars Available) by Pickup Point and Time Slot')
plt.xlabel('Pickup Point and Time Slot')
plt.ylabel('Number of Requests')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Status')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Answer **
#
# I chose a grouped bar chart to visualize the unfulfilled requests by pickup point and time slot because it allows for a clear comparison of the counts of 'Cancelled' and 'No Cars Available' requests within each combination of pickup point and time slot. This helps to easily identify which specific pickup location and time of day has the highest number of each type of unfulfilled request, providing targeted insights into the supply-demand gap.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Answer **
#
# Looking at the grouped bar chart of unfulfilled requests by pickup point and time slot, here are the key insights:
#
# *   **Airport - Evening and Night are critical:** The most significant number of "No Cars Available" requests occur at the **Airport** during the **Evening** and **Night** time slots. This highlights a severe supply shortage at the airport during these peak hours for trips from the airport.
# *   **City - Morning is a major issue:** The highest number of "Cancelled" requests occur in the **City** during the **Morning** time slot. This suggests that drivers in the city might be cancelling requests, potentially due to factors like not wanting to go to the airport during rush hour or other reasons.
# *   **Different problems at different locations and times:** The chart clearly shows that the nature of the unfulfilled requests differs significantly between the Airport and the City and across different time slots. The Airport primarily suffers from a lack of available cars in the evening and night, while the City has a major issue with cancellations in the morning.
# *   **Daytime has fewer unfulfilled requests:** Compared to the rush hours (Morning and Evening/Night), the Daytime slot generally has fewer unfulfilled requests at both pickup points.
#
# These insights pinpoint the specific times and locations where the supply-demand gap is most pronounced and the specific type of unfulfilled request that is most common in those areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer **
#
# Yes, the insights from the grouped bar chart of unfulfilled requests by pickup point and time slot are highly valuable for creating a positive business impact.
#
# **Positive Business Impact:**
#
# *   **Targeted Solutions:** The chart precisely identifies the most critical time slots and pickup points for unfulfilled requests (e.g., "No Cars Available" at the Airport in the Evening/Night, "Cancelled" in the City in the Morning). This allows Uber to develop targeted strategies instead of general ones. For example, they can focus on incentivizing drivers to be at the airport during evening/night or investigate reasons for cancellations in the city during the morning.
# *   **Efficient Resource Allocation:** Knowing the specific hotspots for the supply-demand gap enables more efficient allocation of drivers. Uber can proactively position drivers in areas and at times where demand is high and supply is low.
# *   **Improved Customer Experience:** By addressing the issues at the identified critical points, Uber can significantly reduce wait times and cancellations, leading to a better experience for customers and increased satisfaction.
#
# **Insights that lead to negative growth:**
#
# *   **High Unfulfilled Requests in Specific Hotspots:** The chart clearly highlights the areas with the highest number of unfulfilled requests. These represent significant instances of lost business and revenue. Each cancelled request or instance of "No Cars Available" is a missed transaction.
# *   **Customer Churn:** Repeatedly being unable to get a ride during peak times or from specific locations will likely lead to customers switching to alternative transportation methods, resulting in a loss of market share and long-term negative growth.
# *   **Driver Dissatisfaction (indirectly):** While not directly shown in this chart, a high rate of "No Cars Available" at the Airport might indicate that drivers are not finding it profitable or convenient to be there during those times, potentially leading to driver dissatisfaction or reluctance to take those trips. Similarly, high cancellations in the city could frustrate drivers who have accepted the request.
#
# By directly pinpointing the most problematic areas, the insights from this chart are essential for developing strategies to mitigate negative growth and drive positive business outcomes.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Group by request timestamp and status, then count requests
requests_over_time = df.groupby([df['Request timestamp'].dt.date, 'Status']).size().unstack().fillna(0)

# Plot the trend over time
plt.figure(figsize=(14, 7))
requests_over_time.plot(kind='line', marker='o', ax=plt.gca())
plt.title('Uber Request Trend by Status Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Requests')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Status')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Answer**
#
# I chose a line plot to visualize the Uber request trend by status over time because line plots are ideal for showing how data changes continuously over a period. In this case, it allows us to see the fluctuations in the number of 'Trip Completed', 'Cancelled', and 'No Cars Available' requests across the recorded dates. This helps in identifying any daily patterns, peaks in demand, or periods with a high incidence of unfulfilled requests.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Answer **
#
# Looking at the line plot showing the Uber request trend by status over time, here are the key insights:
#
# *   **Limited Data Range:** The chart only shows data for two distinct dates (November 7th, 2016 and December 7th, 2016). This severely limits the ability to identify long-term trends or seasonal patterns.
# *   **Daily Fluctuation:** For the two dates available, there are clear fluctuations in the number of requests throughout the day, with peaks and dips for each status.
# *   **Consistent Pattern of Unfulfilled Requests:** On both recorded dates, there is a significant number of 'No Cars Available' requests, consistently higher than 'Cancelled' requests and a substantial portion of the total requests. This reinforces the earlier finding about the supply-demand gap.
# *   **Comparison Between the Two Dates:** While the overall pattern of statuses seems somewhat similar on both days, there might be slight variations in the total number of requests or the proportion of each status between November 7th and December 7th.
#
# Due to the limited data points (only two days), it's challenging to draw strong conclusions about trends over a longer period. However, the chart clearly illustrates the presence of unfulfilled requests on the days recorded and hints at daily patterns in demand and supply.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer**
#
# The insights gained from the line plot showing Uber request trends over time have **limited direct positive business impact** due to the very restricted data range (only two days). It is difficult to make strategic decisions based on such a short timeframe.
#
# **Limited Positive Business Impact:**
#
# *   The chart confirms the existence of unfulfilled requests ('Cancelled' and 'No Cars Available') on the days observed, reinforcing the need to address the supply-demand gap.
# *   It shows that there are daily fluctuations in demand and unfulfilled requests, suggesting that time of day is a factor.
#
# **Insights that lead to negative growth:**
#
# *   The persistent presence of a substantial number of 'No Cars Available' and 'Cancelled' requests on both recorded days represents **consistent lost revenue and potential customer dissatisfaction**. Even within this limited timeframe, the chart highlights that a significant portion of demand is not being met.
# *   The limited data itself is a barrier to identifying seasonal or weekly trends, which are crucial for effective business planning and preventing negative growth over longer periods. Without more data, it's hard to know if the observed days are representative or if there are other times with even more severe imbalances.
#
# In conclusion, while the chart confirms the problem, its limited scope restricts the ability to draw comprehensive conclusions for significant positive business impact or to fully understand the patterns leading to negative growth over time. More data is needed for a thorough analysis.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Analyze status distribution during morning peak hours (City) and evening/night peak hours (Airport)

# Filter for requests during morning peak hours (4 AM to 10 AM) from the City
morning_peak_city_df = df[(df['Time Slot'] == 'Morning') & (df['Pickup point'] == 'City')]

# Filter for requests during evening/night peak hours (4 PM to 4 AM) from the Airport
evening_night_peak_airport_df = df[((df['Time Slot'] == 'Evening') | (df['Time Slot'] == 'Night')) & (df['Pickup point'] == 'Airport')]

# Get status counts for each filtered dataframe
morning_peak_city_status_counts = morning_peak_city_df['Status'].value_counts()
evening_night_peak_airport_status_counts = evening_night_peak_airport_df['Status'].value_counts()

# Create pie charts
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.pie(morning_peak_city_status_counts, labels=morning_peak_city_status_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Status Distribution: City - Morning Peak')
plt.axis('equal')

plt.subplot(1, 2, 2)
plt.pie(evening_night_peak_airport_status_counts, labels=evening_night_peak_airport_status_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Status Distribution: Airport - Evening/Night Peak')
plt.axis('equal')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#
# I chose to use two pie charts for Chart 11 to provide a focused and clear visualization of the request status distribution during the identified critical peak times for each major pickup point: the morning peak in the City and the evening/night peak at the Airport. Pie charts are excellent for showing the proportion of different categories within a whole. By creating separate pie charts for these specific scenarios, we can easily compare the percentage of 'Trip Completed', 'Cancelled', and 'No Cars Available' requests in each key problem area, offering a crisp and easy-to-understand view of the prevailing issue (cancellations in the city morning vs. no cars available at the airport evening/night).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Answer**
#
# Looking at the two pie charts in Chart 11, here are the key insights regarding the supply-demand gap during peak hours:
#
# **City - Morning Peak (4 AM to 10 AM):**
#
# *   **High Proportion of Cancellations:** The pie chart for the City during morning peak clearly shows that a significant portion of requests are **Cancelled**. This indicates that even though there is demand, drivers might be unwilling or unable to accept these rides during this busy period, possibly due to traffic or the destination being the airport.
# *   **Lower Proportion of "No Cars Available":** Compared to cancellations, the percentage of "No Cars Available" in the City during morning peak is lower. This suggests that the issue is less about a complete lack of drivers and more about drivers choosing not to take certain requests.
#
# **Airport - Evening/Night Peak (4 PM to 4 AM):**
#
# *   **Dominance of "No Cars Available":** The pie chart for the Airport during evening/night peak reveals a very high proportion of requests with **"No Cars Available"**. This is the most prominent issue at the airport during these hours, indicating a severe shortage of drivers available or willing to pick up passengers from the airport.
# *   **Lower Proportion of Cancellations:** Cancellations from the airport during evening/night peak are a much smaller percentage compared to "No Cars Available." This suggests that when a car is available, the trip is likely to be completed, but the primary problem is the lack of available cars.
#
# **Overall Contrast:** The charts highlight the fundamental difference in the nature of the supply-demand gap at the two key locations during their respective peak times. The City morning peak is characterized by high cancellations, while the Airport evening/night peak is dominated by the lack of available cars.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer Here**
#
# Yes, the insights gained from the pie charts showing status distribution during peak hours are highly impactful for creating a positive business impact.
#
# **Positive Business Impact:**
#
# *   **Precise Problem Identification:** The charts clearly show *what kind* of supply-demand gap exists at the two most problematic areas during their peak times. Knowing that the City's morning peak issue is primarily cancellations while the Airport's evening/night issue is "No Cars Available" allows for precise problem-solving.
# *   **Targeted Strategy Development:** This precise identification enables Uber to develop tailored strategies. For the City morning peak, the focus might be on understanding and mitigating driver cancellation reasons (e.g., route preferences, incentives for airport trips). For the Airport evening/night peak, the focus should be on increasing driver supply at the airport (e.g., waiting area improvements, surge pricing strategies, communication about high demand).
# *   **Improved Resource Allocation:** The insights directly inform how Uber should allocate its resources (drivers) across time and location. They need more drivers willing to go to the airport in the evening/night and potentially incentives for city drivers to accept morning airport trips.
# *   **Enhanced Customer and Driver Experience:** Addressing the root causes of unfulfilled requests in these critical areas will lead to more completed trips, reducing frustration for both riders and drivers and improving overall satisfaction.
#
# **Insights that lead to negative growth:**
#
# *   **High Rates of Unfulfilled Requests in Peak Periods:** The large slices representing 'Cancelled' in the City morning peak and 'No Cars Available' in the Airport evening/night peak are direct indicators of significant lost revenue and negative growth. These are times of high demand where a substantial portion of potential business is being missed.
# *   **Customer Frustration and Churn:** Customers repeatedly facing cancellations in the morning from the city or being unable to find a car at the airport in the evening/night will become frustrated and are highly likely to use alternative transportation services in the future, leading to a loss of market share and long-term negative growth.
#
# These charts provide crucial, actionable insights that directly highlight areas of significant negative growth and point towards the specific nature of the problems that need to be addressed for positive business impact.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Filter for requests from the Airport
airport_requests_df = df[df['Pickup point'] == 'Airport']

# Group by time slot and status, then count requests
airport_status_by_timeslot = airport_requests_df.groupby('Time Slot')['Status'].value_counts().unstack().fillna(0)

# Define the order of time slots
time_slot_order = ['Morning', 'Daytime', 'Evening', 'Night']
airport_status_by_timeslot = airport_status_by_timeslot.reindex(time_slot_order).fillna(0)

# Plot a stacked bar chart
airport_status_by_timeslot.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Uber Request Status Distribution at Airport by Time Slot')
plt.xlabel('Time Slot')
plt.ylabel('Number of Requests')
plt.xticks(rotation=0)
plt.legend(title='Status')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Answer **
#
# I chose a stacked bar chart to visualize the Uber request status distribution at the Airport by time slot because it effectively shows the total number of requests originating from the Airport during each time slot and how those requests are divided among the different statuses ('Trip Completed', 'Cancelled', and 'No Cars Available'). This allows for a clear comparison of the proportion of unfulfilled requests at the Airport across different times of the day, highlighting when the supply-demand gap is most significant at this specific pickup point.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Answer**
#
# Looking at the stacked bar chart showing Uber request status distribution at the Airport by time slot, here are the key insights:
#
# *   **Evening and Night are Major Problem Periods:** The most striking insight is the significantly high number of "No Cars Available" requests during the **Evening** and **Night** time slots at the Airport. This clearly indicates a severe shortage of driver supply during these periods when there is high demand from the airport.
# *   **"No Cars Available" Dominates Unfulfilled Requests:** In the Evening and Night time slots, the "No Cars Available" segment is much larger than the "Cancelled" segment, highlighting that the primary issue is the lack of available drivers rather than passengers cancelling trips after a driver is assigned.
# *   **Morning and Daytime are Relatively Better:** The Morning and Daytime slots at the Airport show a much higher proportion of "Trip Completed" requests and significantly fewer unfulfilled requests compared to the Evening and Night. While there are still some "No Cars Available" and "Cancelled" requests, the imbalance is not as severe.
# *   **Demand Peaks in Evening/Night:** The total height of the bars indicates that the overall number of requests from the Airport is highest during the Evening and Night time slots, coinciding with the peak "No Cars Available" issue.
#
# These insights strongly suggest that the critical supply-demand gap at the Airport occurs in the evening and night, primarily driven by a lack of available drivers to meet the high demand for trips from the airport.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer **
#
# Yes, the insights gained from the stacked bar chart showing request status distribution at the Airport by time slot are highly valuable for creating a positive business impact.
#
# **Positive Business Impact:**
#
# *   **Pinpointing Critical Supply Shortages:** The chart precisely identifies that the most severe supply shortage ("No Cars Available") at the Airport occurs during the Evening and Night time slots. This allows Uber to focus its efforts and resources specifically on these periods.
# *   **Targeted Driver Incentives:** Knowing *when* the driver shortage is most critical at the airport enables Uber to implement targeted incentives (e.g., surge pricing, bonus payments) to encourage drivers to be available at the airport during the evening and night.
# *   **Improved Airport Operations:** The insights can inform operational strategies at the airport, such as optimizing driver waiting areas, improving communication with drivers about demand, and potentially collaborating with airport authorities to facilitate pickups during peak hours.
# *   **Increased Completed Trips from Airport:** By addressing the supply shortage during peak times, Uber can significantly increase the number of completed trips from the airport, leading to increased revenue and market share for airport transportation.
# *   **Enhanced Customer Satisfaction:** Reducing the high number of "No Cars Available" instances at the airport will drastically improve the customer experience for travelers arriving during the evening and night, leading to higher satisfaction and loyalty.
#
# **Insights that lead to negative growth:**
#
# *   **High "No Cars Available" Rate in Evening/Night:** The most significant insight leading to negative growth is the extremely high proportion of "No Cars Available" requests at the Airport during the Evening and Night. This represents a substantial amount of lost business and revenue during peak demand periods.
# *   **Customer Frustration and Churn:** Travelers arriving at the airport in the evening or night who repeatedly cannot find an Uber due to lack of available cars will become frustrated and are likely to seek alternative transportation (taxis, shuttles, etc.). This leads to customer churn and a loss of future business.
# *   **Damage to Brand Reputation:** A reputation for being unreliable at the airport during peak hours can negatively impact Uber's brand image, potentially deterring both new and existing customers from using the service for airport travel or even other trips.
#
# By clearly identifying the critical time slots at the Airport with severe supply shortages, the insights from this chart are essential for developing strategies to mitigate these negative growth factors and capitalize on the high demand during these periods.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Filter for requests from the City
city_requests_df = df[df['Pickup point'] == 'City']

# Group by time slot and status, then count requests
city_status_by_timeslot = city_requests_df.groupby('Time Slot')['Status'].value_counts().unstack().fillna(0)

# Define the order of time slots
time_slot_order = ['Morning', 'Daytime', 'Evening', 'Night']
city_status_by_timeslot = city_status_by_timeslot.reindex(time_slot_order).fillna(0)

# Plot a stacked bar chart
city_status_by_timeslot.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Uber Request Status Distribution in City by Time Slot')
plt.xlabel('Time Slot')
plt.ylabel('Number of Requests')
plt.xticks(rotation=0)
plt.legend(title='Status')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Answer **
#
# I chose a stacked bar chart to visualize the Uber request status distribution in the City by time slot because it effectively shows the total number of requests originating from the City during each time slot and how those requests are divided among the different statuses ('Trip Completed', 'Cancelled', and 'No Cars Available'). This allows for a clear comparison of the proportion of unfulfilled requests in the City across different times of the day, highlighting when the supply-demand gap is most significant at this specific pickup point and the nature of the unfulfilled requests (cancellations vs. no cars available).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Answer**
#
# Looking at the stacked bar chart showing Uber request status distribution in the City by time slot, here are the key insights:
#
# *   **Morning Peak has High Cancellations:** The most prominent issue in the City is the high number of **Cancelled** requests during the **Morning** time slot (4 AM to 10 AM). This suggests a significant supply-demand mismatch where drivers might be cancelling rides, possibly due to the destination (e.g., not wanting to go to the airport during rush hour) or other factors.
# *   **Evening/Night has High "No Cars Available" and Completed Trips:** The Evening and Night time slots in the City show a high number of both "No Cars Available" requests and "Trip Completed" requests. This indicates high overall demand during these periods, and while many trips are completed, there's still a substantial portion where no cars are available, suggesting a general supply constraint during these busy hours.
# *   **Daytime is Relatively Balanced:** The Daytime slot in the City appears to have a more balanced distribution of statuses, with a higher proportion of completed trips and fewer unfulfilled requests compared to the peak hours.
# *   **Different Problems than Airport:** Comparing this to the Airport chart (Chart 12), the City's morning peak issue is primarily cancellations, whereas the Airport's evening/night issue is predominantly "No Cars Available." This highlights the need for different strategies for each pickup point.
#
# These insights pinpoint the specific times in the City where the supply-demand gap is most significant and the nature of the problem (cancellations in the morning, general supply constraint in the evening/night).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Answer **
#
# Yes, the insights gained from the stacked bar chart showing request status distribution in the City by time slot are highly valuable for creating a positive business impact.
#
# **Positive Business Impact:**
#
# *   **Targeted Solutions:** The chart precisely identifies the most critical time slot in the City (Morning) and the primary issue during that time (cancellations). This allows Uber to develop targeted strategies to address driver behavior or incentives during the morning peak in the City. It also shows that in the Evening/Night, while many trips are completed, there's a general supply constraint, indicating a need for more drivers during those hours.
# *   **Improved Resource Allocation:** Knowing the specific time slots and the nature of the problem in the City enables more efficient allocation of drivers. Uber can focus on reducing cancellations in the morning and increasing overall driver supply in the evening/night.
# *   **Enhanced Customer Experience:** Addressing the high cancellation rate in the City morning peak and reducing "No Cars Available" instances in the evening/night will improve the reliability of Uber's service in the city, leading to higher customer satisfaction.
#
# **Insights that lead to negative growth:**
#
# *   **High Cancellation Rate in City Morning Peak:** The significant number of cancelled requests in the City during the Morning peak represents substantial lost revenue and negative growth. These are instances where demand exists but is not being met due to driver behavior or other factors leading to cancellations.
# *   **"No Cars Available" in City Evening/Night:** While not as severe as at the Airport, the presence of a significant number of "No Cars Available" requests in the City during the Evening and Night also represents lost business and potential customer frustration, contributing to negative growth.
# *   **Customer Churn:** Customers who repeatedly experience cancellations or difficulty finding a car in the City during peak hours may become frustrated and choose alternative transportation, leading to a loss of market share.
#
# By clearly identifying the critical time slots in the City and the specific nature of the supply-demand gap, the insights from this chart are essential for developing strategies to mitigate these negative growth factors and improve service efficiency.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Select only numerical columns for correlation analysis
numerical_cols = df.select_dtypes(include=np.number).columns

# Calculate the correlation matrix
correlation_matrix = df[numerical_cols].corr()

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Answer**
#
# I chose a correlation heatmap to visualize the relationships between the numerical variables in the dataset because a heatmap is an effective way to display a correlation matrix. The color intensity and the annotated values in the heatmap make it easy to quickly identify the strength and direction of the linear correlation between each pair of numerical variables. This helps in understanding which numerical factors might be related to each other.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Answer**
#
# Looking at the correlation heatmap of the numerical variables, here are the key insights:
#
# *   **Strong positive correlation between 'Request id' and 'Request Month':** There is a strong positive correlation (around 0.87) between 'Request id' and 'Request Month'. This is expected as 'Request id' likely increases sequentially with each new request, and the data spans across two different months (November and December). As time progresses, both the Request ID and the month value increase, leading to this correlation.
# *   **Moderate positive correlation between 'Request id' and 'Request hour':** There is a moderate positive correlation (around 0.49) between 'Request id' and 'Request hour'. This also makes sense as requests within a day are likely ordered sequentially, and as the day progresses (higher request hour), the Request ID will generally increase.
# *   **Moderate positive correlation between 'Request hour' and 'Trip Duration':** There is a moderate positive correlation (around 0.22) between 'Request hour' and 'Trip Duration'. This suggests that trips might tend to be slightly longer during later hours of the day. This could be influenced by factors like traffic patterns that change throughout the day.
# *   **Weak or negligible correlations:** Most other numerical variable pairs show weak or negligible correlations (values close to 0). This includes the correlation between 'Driver id' and other variables, as well as the correlation between 'Request Month' and 'Trip Duration'. The correlation between 'Request Year' and other variables is not available because there is only one unique year in the dataset (2016).
# *   **Missing Data Impact:** The heatmap also implicitly shows the impact of missing data, as the 'Request Year' column has no variation, resulting in NaN correlations with other variables.
#
# Overall, the heatmap reveals some expected correlations related to the sequential nature of request IDs and the time of the request, as well as a slight positive correlation between request hour and trip duration. It also highlights that 'Driver id' does not have a strong linear relationship with the other numerical variables in this dataset.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Chart - 15 visualization code
# Box plot of Trip Duration by Time Slot for completed trips
plt.figure(figsize=(10, 6))
sns.boxplot(data=completed_trips_df, x='Time Slot', y='Trip Duration', order=['Morning', 'Daytime', 'Evening', 'Night'])
plt.title('Distribution of Trip Durations by Time Slot (Completed Trips)')
plt.xlabel('Time Slot')
plt.ylabel('Trip Duration (minutes)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Answer Here.**
#
# I chose a pair plot to visualize the relationships between the numerical variables in the dataset because it provides a matrix of scatter plots showing the relationship between each pair of numerical variables, as well as histograms on the diagonal showing the distribution of each individual variable. This allows for a quick overview of potential correlations, patterns, and distributions among all numerical variables simultaneously.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Answer Here**
#
# Looking at the box plot showing the distribution of trip durations by time slot for completed trips, here are some potential insights:
#
# *   **Variation in Median Trip Duration:** The median trip duration (the line inside the box) appears to vary across the different time slots. This suggests that the typical length of a completed Uber trip is not consistent throughout the day.
# *   **Spread of Trip Durations:** The length of the boxes (interquartile range) and the whiskers indicate the variability in trip durations within each time slot. Some time slots might have a wider spread of trip lengths than others.
# *   **Presence of Outliers:** The points outside the whiskers represent potential outliers, which are unusually long trips. The number and distribution of these outliers can also vary by time slot.
# *   **Potential for Longer Trips in Certain Slots:** Based on the median and the upper quartile, some time slots (e.g., Evening or Night) might tend to have slightly longer completed trips on average compared to others, possibly due to factors like traffic or longer distances traveled during those times.
#
# These insights help in understanding how trip lengths are distributed throughout the day for completed rides, which can be useful for estimating arrival times and optimizing driver schedules.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# **Answer**
#
# To achieve the business objective of reducing the Uber supply-demand gap, particularly for airport transportation, the client should focus on targeted strategies based on the identified peak problem areas:
#
# 1.  **Address Morning Peak Cancellations in the City:** Investigate the reasons behind high driver cancellations in the City during morning rush hours. This could involve incentives for drivers accepting airport trips from the city, optimizing routing to minimize travel time during peak traffic, or communicating expected trip durations more clearly.
# 2.  **Increase Driver Supply at the Airport During Evening/Night Peak:** Implement strategies to significantly increase the number of available drivers at the Airport during the evening and night time slots, where the "No Cars Available" issue is most severe. This could include surge pricing incentives during these hours, creating better waiting facilities for drivers at the airport, or using predictive modeling to anticipate demand and position drivers proactively.
# 3.  **Improve Communication and Transparency:** Enhance communication with both drivers and riders about expected wait times and potential surge pricing during peak hours and at high-demand locations like the airport. This can help manage expectations and reduce cancellations.
# 4.  **Analyze Driver Behavior:** Conduct further analysis on driver behavior during peak hours and at critical locations to understand why requests are being cancelled or not accepted (e.g., trip distance, destination, driver location relative to the request).

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **Conclusion**
#
# Based on the exploratory data analysis of the Uber request data, the following key conclusions can be drawn regarding the supply-demand gap:
#
# 1.  **Significant Unfulfilled Demand:** A substantial portion of Uber requests remain unfulfilled, primarily due to cancellations and the lack of available cars. This highlights a significant gap between the demand for Uber rides and the available supply.
# 2.  **Peak Hour Imbalances:** The supply-demand gap is particularly severe during specific peak hours. The morning rush hour (roughly 4 AM to 10 AM) in the City experiences a high rate of cancellations, suggesting drivers might be reluctant to accept certain trips during this busy period, possibly due to traffic or destination. The evening and night hours (roughly 4 PM to 4 AM) at the Airport suffer from a critical shortage of available cars, indicating insufficient driver supply to meet the high demand from arriving passengers.
# 3.  **Location-Specific Problems:** The nature of the supply-demand gap differs between pickup locations. The City's main issue during its peak is cancellations, while the Airport's main issue during its peak is the lack of available vehicles.
# 4.  **Limited Data Scope:** The analysis was limited by the availability of data for only two specific dates (November 7th and December 7th, 2016) and only two days of the week (Monday and Wednesday). A more comprehensive dataset spanning a longer period and covering all days of the week would be beneficial for identifying broader trends and seasonal patterns.
#
# **Recommendations to address the gap:**
#
# *   Implement targeted incentives to encourage drivers to be available in the City during morning peak hours and at the Airport during evening/night peak hours.
# *   Investigate the specific reasons for driver cancellations in the City during the morning and address those factors (e.g., improve routing algorithms, manage rider expectations on wait times for certain destinations).
# *   Optimize driver positioning and allocation strategies, particularly at the Airport during evening and night, potentially using predictive analytics to anticipate demand.
# *   Improve communication with both drivers and riders regarding expected demand, surge pricing, and potential wait times during peak periods.
#
# Addressing these specific issues at the identified critical times and locations is crucial for reducing the supply-demand gap, improving operational efficiency, and enhancing customer satisfaction for Uber's services, especially for airport transportation.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA UBER SUPPLY DEMAND GAP !!!***
