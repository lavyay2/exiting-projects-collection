# %% [markdown]
# <a href="https://colab.research.google.com/github/lavyay2/exiting-projects-collection/blob/main/pwskills%20mentor%20guidence%20project%20of%20python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Income Classification Project**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
header = ["age", "workclass", "someid", "education", "education_num", "marital_status", "occupation", "relationship","race", "sex", "capital-gain", "capital_loss", "hours_per_week", "native_country", "class"]

df = pd.read_csv("/content/adult (1).csv", header = None, names = header, na_values = [' ?'])

# %%
df
# Out:
#        age          workclass  someid    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.head()
# Out:
#    age          workclass  someid   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital_loss  hours_per_week  native_country   class
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.tail()
# Out:
#        age      workclass  someid    education  education_num  \
# 32556   27        Private  257302   Assoc-acdm             12
# 32557   40        Private  154374      HS-grad              9
# 32558   58        Private  151910      HS-grad              9
# 32559   22        Private  201490      HS-grad              9
# 32560   52   Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital-gain  capital_loss  hours_per_week  native_country   class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   someid          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  31978 non-null  object
#  14  class           32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# someid             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# class             object
# dtype: object

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.describe()
# Out:
#                 age        someid  education_num  capital-gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# someid               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital_loss         0
# hours_per_week       0
# native_country     583
# class                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.workclass.unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', nan, ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'someid', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'class'],
#       dtype='object')

# %%
df
# Out:
#        age          workclass  someid    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.isna().sum()
# Out:
# age                  0
# workclass         1836
# someid               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital_loss         0
# hours_per_week       0
# native_country     582
# class                0
# dtype: int64

# %%
df.native_country.unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
for col in [col for col in df.columns if df[col].dtype == "object"]:
    df[col] = df[col].str.strip()

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# someid             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# class             object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()

for col in [col for col in df.columns if df[col].dtype == "object"]:
    df[col] = label.fit_transform(df[col])

# %%
df
# Out:
#        age  workclass  someid  education  education_num  marital_status  \
# 0       39          6   77516          9             13               4
# 1       50          5   83311          9             13               2
# 2       38          3  215646         11              9               0
# 3       53          3  234721          1              7               2
# 4       28          3  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          3  257302          7             12               2
# 32557   40          3  154374         11              9               2
# 32558   58          3  151910         11              9               6
# 32559   22          3  201490         11              9               4
# 32560   52          4  287927         11              9               2
#
#        occupation  relationship  race  sex  capital-gain  capital_loss  \
# ...

# %%
df.dtypes
# Out:
# age               int64
# workclass         int64
# someid            int64
# education         int64
# education_num     int64
# marital_status    int64
# occupation        int64
# relationship      int64
# race              int64
# sex               int64
# capital-gain      int64
# capital_loss      int64
# hours_per_week    int64
# native_country    int64
# class             int64
# dtype: object

# %%
y = df['class']
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: class, Length: 32537, dtype: int64

# %%
X = df.drop("class", axis = 1)
X
# Out:
#        age  workclass  someid  education  education_num  marital_status  \
# 0       39          6   77516          9             13               4
# 1       50          5   83311          9             13               2
# 2       38          3  215646         11              9               0
# 3       53          3  234721          1              7               2
# 4       28          3  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          3  257302          7             12               2
# 32557   40          3  154374         11              9               2
# 32558   58          3  151910         11              9               6
# 32559   22          3  201490         11              9               4
# 32560   52          4  287927         11              9               2
#
#        occupation  relationship  race  sex  capital-gain  capital_loss  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=1)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((26029, 14), (6508, 14), (26029,), (6508,))

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.7991702519975414

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8070067609096496

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8623232944068838

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8020897357098955

# %%
from xgboost import XGBClassifier
clf = XGBClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8740012292563

# %%
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8531038721573448

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf = GradientBoostingClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.866779348494161

# %%
round(accuracy_score(y_test, y_pred)*100, 2)
# Out:
# 86.68

# %% [markdown]
# # Task
# Generate Python code to create visualizations for numerical and categorical features in a dataset.

# %% [markdown]
# ## Visualize numerical feature distributions
#
# ### Subtask:
# Generate histograms or box plots to visualize the distributions of numerical features.

# %% [markdown]
# **Reasoning**:
# Identify numerical columns and create histograms and box plots for each to visualize their distributions and potential outliers.

# %%
numerical_cols = df.select_dtypes(include=np.number).columns

for col in numerical_cols:
    plt.figure(figsize=(10, 5))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

    plt.figure(figsize=(10, 5))
    sns.boxplot(x=df[col])
    plt.title(f'Box Plot of {col}')
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# # **Income Classification Project**
#  summary of the project:
#
# Dataset Acquisition and Initial Exploration: We began by loading the "adult (1).csv" dataset, a rich source of demographic and work-related data. Initial exploration through various pandas functions provided a foundational understanding of its structure, data types, and dimensions.
# Data Cleansing and Preparation: A crucial step involved identifying and handling missing values and duplicate entries to ensure data integrity. We then proceeded to preprocess the data, which included standardizing categorical features through encoding, preparing it for subsequent modeling phases.
# Feature and Target Separation & Data Partitioning: The dataset was clearly delineated into features (X) for model training and the target variable (y) representing the income class. This prepared the data for partitioning into training and testing sets, a standard practice for evaluating model performance on unseen data.
# Diverse Model Training and Performance Evaluation: A suite of powerful classification algorithms was employed, ranging from traditional models like Logistic Regression and Decision Trees to ensemble methods like Random Forests, Gradient Boosting, and XGBoost. Each model was rigorously trained on the prepared data, and their performance was assessed using accuracy scores on the test set, providing insights into their predictive capabilities.
# Comprehensive Data Visualization: To gain deeper insights into the dataset's characteristics, we generated visualizations for both numerical and categorical features. Histograms and box plots revealed the distributions and potential outliers within numerical columns, while bar plots and count plots illustrated the frequency and distribution of categories within categorical features. These visualizations provided a clear picture of the data's underlying patterns.
# This project successfully demonstrates a complete machine learning workflow, from data loading and preprocessing to training and evaluating various classification models, culminating in insightful data visualizations
